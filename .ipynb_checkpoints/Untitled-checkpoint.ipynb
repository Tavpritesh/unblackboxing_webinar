# %%
# %load_ext autoreload
# %autoreload 2 

from sklearn.datasets import fetch_lfw_people

from facial_recognition.preprocessing import lfw_train_test_split, FacePreprocessor, tensor2img, img2tensor
# from facial_recognition.model import FaceClassifier
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lfw_people = fetch_lfw_people(min_faces_per_person=200, resize=1.0, color=True, 
                              data_home='/mnt/ml-team/homes/jakub.czakon/.data/scikit_learn_data')

(X_train, y_train), (X_test,y_test) = lfw_train_test_split(lfw_people, train_size=0.75)

face_prep = FacePreprocessor()
X_train, y_train = face_prep.fit_transform(X=X_train, y=y_train)
X_test, y_test = face_prep.transform(X=X_test, y=y_test)

# %%
lfw_people.keys()
# Out:
# dict_keys(['images', 'target_names', 'data', 'target', 'DESCR'])

# %%
import matplotlib.pyplot as plt

dir_path = '/mnt/ml-team/homes/jakub.czakon/.unblackboxing_webinar_data/data/faces/images'
filepaths = []
for i, image in enumerate(lfw_people['images']):
    filepath = '%s/%s.jpg'%(dir_path,i)
    plt.imsave(image,filepath)
    plt.show()
    filepaths.append(filepath)
    break

# %%
face_classifier = FaceClassifier(input_shape=(125,94),classes=158)

# %%
face_classifier.train((X_train, y_train), (X_test,y_test), batch_size=32, epochs=100)
# Out:
# Train on 78 samples, validate on 1482 samples
# Epoch 1/100
# 78/78 [==============================] - 2s - loss: 5.2150 - acc: 0.1923 - val_loss: 8.6940 - val_acc: 0.1532
# Epoch 2/100
# 78/78 [==============================] - 1s - loss: 7.0639 - acc: 0.1410 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 3/100
# 78/78 [==============================] - 1s - loss: 10.7140 - acc: 0.2821 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 4/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 5/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 6/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 7/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 8/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 9/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 10/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 11/100
# 78/78 [==============================] - 1s - loss: 10.3321 - acc: 0.3590 - val_loss: 10.6584 - val_acc: 0.3387
# Epoch 12/100
# 64/78 [=======================>......] - ETA: 0s - loss: 10.8293 - acc: 0.3281
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f18bb09e1d62> in <module>()
# ----> 1 face_classifier.train((X_train, y_train), (X_test,y_test), batch_size=32, epochs=100)
#
# /home/jakub.czakon/projects/unblackboxing_webinar/facial_recognition/model.py in train(self, train, valid, **kwargs)
#      36         self.facenet_.fit(X_train, y_train,
#      37                           validation_data=[X_valid, y_valid],
# ---> 38                           callbacks=None, **kwargs)
#      39
#      40     def predict():
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
#    1497                               callback_metrics=callback_metrics,
# -> 1498                               initial_epoch=initial_epoch)
#    1499
#    1500     def evaluate(self, x, y, batch_size=32, verbose=1, sample_weight=None):
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch)
#    1162                         val_outs = self._test_loop(val_f, val_ins,
#    1163                                                    batch_size=batch_size,
# -> 1164                                                    verbose=0)
#    1165                         if not isinstance(val_outs, list):
#    1166                             val_outs = [val_outs]
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/keras/engine/training.py in _test_loop(self, f, ins, batch_size, verbose)
#    1264                 ins_batch = _slice_arrays(ins, batch_ids)
#    1265
# -> 1266             batch_outs = f(ins_batch)
#    1267             if isinstance(batch_outs, list):
#    1268                 if batch_index == 0:
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2227         session = get_session()
#    2228         updated = session.run(self.outputs + [self.updates_op],
# -> 2229                               feed_dict=feed_dict)
#    2230         return updated[:len(self.outputs)]
#    2231
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /home/jakub.czakon/.env/dl_py3/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
from keras.applications.vgg16 import VGG16
from keras.layers import Input,Flatten,Dense
from keras.models import Model
face_input = Input(batch_shape=(None,) + (125, 94, 3))

model = VGG16(input_tensor=face_input, 
              weights='imagenet', 
              include_top=False)
# Out:
# Using TensorFlow backend.

# %%
model.()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-5264cd85cfb9> in <module>()
# ----> 1 model.pop()
#
# AttributeError: 'Model' object has no attribute 'pop'

# %%
#Use the generated model 
model_output = model(face_input)

#Add the fully-connected layers 
x = Flatten(name='flatten')(model_output)
x = Dense(512, activation='relu')(x)
output = Dense(5, activation='softmax')(x)

facenet = Model(face_input, output)
facenet.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
x = model.output
x = Flatten()(x)
x = Dense(512, activation='relu')(x)
output = Dense(classes, activation='softmax')(x)

facenet = Model(face_input, output)
facenet.compile(optimizer='adam',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
for i,l in enumerate(model.layers):
    print(i,l.name)
# Out:
# 0 input_1
# 1 block1_conv1
# 2 block1_conv2
# 3 block1_pool
# 4 block2_conv1
# 5 block2_conv2
# 6 block2_pool
# 7 block3_conv1
# 8 block3_conv2
# 9 block3_conv3
# 10 block3_pool
# 11 block4_conv1
# 12 block4_conv2
# 13 block4_conv3
# 14 block4_pool
# 15 block5_conv1
# 16 block5_conv2
# 17 block5_conv3
# 18 block5_pool
