# %%
# %load_ext autoreload
# %autoreload 2 


import pandas as pd

from sklearn.externals import joblib

from keras.models import load_model

import eli5
from eli5.lime import TextExplainer

from twitter_sentiment.preprocessing import tweet_train_test_split, TweetPreprocessor
from twitter_sentiment.model import TweetClassifier
from twitter_sentiment.inference import TweetPredictor


PREP_FILEPATH = '/mnt/ml-team/homes/jakub.czakon/.unblackboxing_webinar_data/models/tweet_preprocessor.pkl'
CONV_MODEL_FILEPATH = '/mnt/ml-team/homes/jakub.czakon/.unblackboxing_webinar_data/models/tweetnetConv1D.h5py'
LSTM_MODEL_FILEPATH = '/mnt/ml-team/homes/jakub.czakon/.unblackboxing_webinar_data/models/tweetnetLSTM.h5py'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tweet_preprocessor = joblib.load(PREP_FILEPATH)
tweet_classifier_conv1d = load_model(CONV_MODEL_FILEPATH)
tweet_classifier_lstm = load_model(LSTM_MODEL_FILEPATH)

# %%
tweet_predictor_conv1d = TweetPredictor(tweet_preprocessor, tweet_classifier_conv1d)
tweet_predictor_lstm = TweetPredictor(tweet_preprocessor, tweet_classifier_lstm)

# %%
text = 'This stupid madness will make me sign up for neptune early adopters'

# %%
print(tweet_predictor_conv1d.predict([text]),tweet_predictor_lstm.predict([text]))

# %% [markdown]
# # Resources
# http://eli5.readthedocs.io/en/latest/tutorials/black-box-text-classifiers.html
#
# http://parrotprediction.com/105-python-libraries-for-data-analysis-nobody-told-you-about/

# %%
te = TextExplainer()
te.fit(text, tweet_predictor_conv1d.predict_proba);

# %%
te.show_prediction(target_names=['negative','positive'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=positive
#
# </b>
#
#
#     (probability <b>0.203</b>, score <b>-1.369</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.91%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.226
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.595
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 94.54%); opacity: 0.81" title="-0.119">this</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 60.00%); opacity: 1.00" title="-2.050">stupid</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.78%); opacity: 0.81" title="0.056">madness</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 88.07%); opacity: 0.84" title="0.364">will</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 83.69%); opacity: 0.86" title="0.569">make</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.58%); opacity: 0.81" title="-0.061">me</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 82.29%); opacity: 0.86" title="0.640">sign</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 92.00%); opacity: 0.82" title="0.206">up</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.71%); opacity: 0.81" title="0.084">for</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.07%); opacity: 0.80" title="0.049">neptune</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 75.76%); opacity: 0.90" title="-1.002">early</span><span style="opacity: 0.80"> adopters</span>
#     </p>

# %%
te.show_weights()

# %%
te = TextExplainer()
te.fit(text, tweet_predictor_lstm.predict_proba);

# %%
te.show_prediction(target_names=['negative','positive'])

# %%
te.show_weights()
# Out:
# Explanation(estimator="SGDClassifier(alpha=0.001, average=False, class_weight=None, epsilon=0.1,\n       eta0=0.0, fit_intercept=True, l1_ratio=0.15,\n       learning_rate='optimal', loss='log', n_iter=5, n_jobs=1,\n       penalty='elasticnet', power_t=0.5,\n       random_state=<mtrand.RandomState object at 0x7f70646c6798>,\n       shuffle=True, verbose=0, warm_start=False)", description="\nFeatures with largest coefficients.\nCaveats:\n1. Be careful with features which are not\n   independent - weights don't show their importance.\n2. If scale of input features is different then scale of coefficients\n   will also be different, making direct comparison between coefficient values\n   incorrect.\n3. Depending on regularization, rare features sometimes may have high\n   coefficients; this doesn't mean they contribute much to the\n   classification result for most examples.\n", error=None, method='linear model', is_regression=False, targets=[TargetExplanation(target=1, feature_weights=FeatureWeights(pos=[FeatureWeight(feature='sign', weight=0.41721839303247243, std=None, value=None), FeatureWeight(feature='will', weight=0.35758365248487345, std=None, value=None), FeatureWeight(feature='make me', weight=0.28780052226348973, std=None, value=None), FeatureWeight(feature='<BIAS>', weight=0.22599388549152688, std=None, value=None), FeatureWeight(feature='me sign', weight=0.22260062606231146, std=None, value=None), FeatureWeight(feature='up', weight=0.20584162247043528, std=None, value=None), FeatureWeight(feature='make', weight=0.17276145717615618, std=None, value=None), FeatureWeight(feature='madness', weight=0.15824708934233606, std=None, value=None), FeatureWeight(feature='this', weight=0.15588531612652395, std=None, value=None), FeatureWeight(feature='will make', weight=0.1086007727538105, std=None, value=None), FeatureWeight(feature='neptune early', weight=0.10385323937429516, std=None, value=None), FeatureWeight(feature='for', weight=0.098560065186392209, std=None, value=None)], neg=[FeatureWeight(feature='stupid', weight=-1.774696370929767, std=None, value=None), FeatureWeight(feature='early', weight=-1.1059777515403715, std=None, value=None), FeatureWeight(feature='me', weight=-0.57137697229208984, std=None, value=None), FeatureWeight(feature='this stupid', weight=-0.27496089914628652, std=None, value=None), FeatureWeight(feature='madness will', weight=-0.10215656376730863, std=None, value=None), FeatureWeight(feature='neptune', weight=-0.040557454638240405, std=None, value=None), FeatureWeight(feature='for neptune', weight=-0.014243149473217349, std=None, value=None)], pos_remaining=0, neg_remaining=0), proba=None, score=None, weighted_spans=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None)
