# %%
import pandas as pd

filepath = '/mnt/ml-team/homes/jakub.czakon/.unblackboxing_webinar_data/data/tweets/Sentiment Analysis Dataset.csv'

# %%
d = pd.read_csv(filepath, error_bad_lines=False)
d.head()
# Out:
# Skipping line 8836: expected 4 fields, saw 5
#
# Skipping line 535882: expected 4 fields, saw 7
#    ItemID  Sentiment SentimentSource  \
# 0       1          0    Sentiment140
# 1       2          0    Sentiment140
# 2       3          1    Sentiment140
# 3       4          0    Sentiment140
# 4       5          0    Sentiment140
#
#                                        SentimentText
# 0                       is so sad for my APL frie...
# 1                     I missed the New Moon trail...
# 2                            omg its already 7:30 :O
# 3            .. Omgaga. Im sooo  im gunna CRy. I'...
# 4           i think mi bf is cheating on me!!!   ...

# %%
d
# Out:
#           ItemID  Sentiment SentimentSource  \
# 0              1          0    Sentiment140
# 1              2          0    Sentiment140
# 2              3          1    Sentiment140
# 3              4          0    Sentiment140
# 4              5          0    Sentiment140
# 5              6          0    Sentiment140
# 6              7          1    Sentiment140
# 7              8          0    Sentiment140
# 8              9          1    Sentiment140
# 9             10          1    Sentiment140
# 10            11          0    Sentiment140
# 11            12          1    Sentiment140
# 12            13          0    Sentiment140
# 13            14          0    Sentiment140
# 14            15          0    Sentiment140
# 15            16          0    Sentiment140
# 16            17          0    Sentiment140
# 17            18          1    Sentiment140
# 18            19          0    Sentiment140
# 19            20          0    Sentiment140
# ...

# %%
with open(filepath , 'r+') as f:
    good_lines = []
    for i,line in enumerate(f):
        sp_line = line.split(',')
        if len(sp_line) != 4:
            print(i)
# Out:
# 17
# 28
# 29
# 37
# 44
# 49
# 69
# 76
# 81
# 83
# 94
# 99
# 107
# 113
# 116
# 118
# 123
# 136
# 138
# 141
# 149
# 157
# 158
# 161
# 172
# 174
# 181
# 182
# 186
# 189
# 195
# 196
# 199
# 200
# 204
# 205
# 206
# 219
# 222
# 223
# 226
# 232
# 236
# 238
# 252
# 253
# 255
# 258
# 263
# 267
# 268
# 269
# 271
# 272
# 273
# 288
# 303
# 308
# 313
# 315
# 324
# 330
# 333
# 338
# 352
# 353
# 382
# 394
# 396
# 402
# 411
# 419
# 420
# 428
# 451
# 454
# 456
# 457
# 465
# 468
# 469
# 470
# 477
# 485
# 504
# 521
# 523
# 531
# 535
# 536
# 542
# 547
# 549
# 559
# 563
# 565
# 581
# 583
# 584
# 586
# 590
# 609
# 620
# 627
# 642
# 643
# 657
# 660
# 669
# 670
# 673
# 683
# 698
# 699
# 700
# 701
# 703
# 709
# 715
# 718
# 734
# 741
# 747
# 748
# 749
# 750
# 751
# 753
# 758
# 759
# 761
# 762
# 770
# 772
# 773
# 775
# 783
# 785
# 798
# 801
# 802
# 803
# 807
# 808
# 813
# 815
# 822
# 825
# 828
# 831
# 839
# 842
# 845
# 848
# 853
# 856
# 858
# 876
# 879
# 888
# 896
# 897
# 902
# 904
# 911
# 919
# 922
# 927
# ...
